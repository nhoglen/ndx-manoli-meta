# %%
from datetime import datetime, date
import os
import numpy as np
from uuid import uuid4

from pynwb import NWBHDF5IO, NWBFile, TimeSeries
from pynwb.file import Subject
from pynwb.behavior import (
    BehavioralEpochs,
    BehavioralEvents,
    BehavioralTimeSeries,
    CompassDirection,
    EyeTracking,
    Position,
    PupilTracking,
    SpatialSeries,
)
from pynwb.epoch import TimeIntervals
from pynwb.image import ImageSeries

from ndx_manoli_meta import AssayMetadata

# %%
# NWB metadata
cohort_tag = "test1"
GT = 'behavior'
sdate = date(2024,3,26)
session_description = f'Testing files with new extension.'
experimenter = [
        "Hoglen, Nerissa",
    ]
lab='Manoli'
session_id = 'test1a'
subj = 'T0001'

assay = "partner_preference_test"
exclude_flag = False
duration = 10800.0
room = 'Platyzilla'
timeline = 'sensitized'
ethogram = 'mark1'
experimenter = 'Gina Williams'
timeline_complete = True
colors = np.array([100.0, 100.0, 100.0])
peartag = 'E0001'
seartag = 'E0002'
pGT = 'mut'
sGT = 'WT'
days = 0
pChamb = 'right'
PPT_lane = 2
desc = 'Standard tethered 3 chamber PPT.'
annos = os.path.join('pretend','path','tofile')

nwbfile = NWBFile(
    session_description=session_description,
    identifier = str(uuid4()),
    session_start_time = datetime.now(),
    lab=lab,
    experimenter=experimenter,
    session_id = session_id,
)

# get session specific subject data
nwbfile.subject = Subject(
    subject_id = subj,
    species = 'Microtus ochrogaster',
    sex = 'F',
    genotype = 'WT'
)

meta = AssayMetadata(
                        assay_type=assay,
                        exclude_flag=exclude_flag,
                        duration=duration,
                        room=room,
                        timeline=timeline,
                        ethogram=ethogram,
                        timeline_complete=timeline_complete,
                        colors=colors,
                        assay_type__partner_ID=peartag,
                        assay_type__partner_GT=pGT,
                        assay_type__days_post_pairing=days,
                        assay_type__stranger_ID=seartag,
                        assay_type__stranger_GT=sGT,
                        assay_type__PPT_lane = PPT_lane,
                        assay_type__partner_chamber = pChamb,
                        assay_type__description = desc,
                        assay_type__annotations = annos
                        )

# Add the test LabMetaDataExtensionExample to the NWBFile
nwbfile.add_lab_meta_data(lab_meta_data=meta)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[8], line 49
#      41 # get session specific subject data
#      42 nwbfile.subject = Subject(
#      43     subject_id = subj,
#      44     species = 'Microtus ochrogaster',
#      45     sex = 'F',
#      46     genotype = 'WT'
#      47 )
# ---> 49 meta = AssayMetadata(
#      50                         assay_type=assay,
#      51                         exclude_flag=exclude_flag,
#      52                         duration=duration,
#      53                         room=room,
#      54                         timeline=timeline,
#      55                         ethogram=ethogram,
#      56                         experimenter=experimenter,
#      57                         timeline_complete=timeline_complete,
#      58                         colors=colors,
#      59                         assay_type__partner_ID=peartag,
#      60                         assay_type__partner_GT=pGT,
#      61                         assay_type__days_post_pairing=days,
#      62                         assay_type__stranger_ID=seartag,
#      63                         assay_type__stranger_GT=sGT,
#      64                         assay_type__PPT_lane = PPT_lane,
#      65                         assay_type__partner_chamber = pChamb,
#      66                         assay_type__description = desc,
#      67                         assay_type__annotations = annos
#      68                         )
#      70 # Add the test LabMetaDataExtensionExample to the NWBFile
#      71 nwbfile.add_lab_meta_data(lab_meta_data=meta)
#
# File /opt/anaconda3/envs/NWB/lib/python3.9/site-packages/hdmf/utils.py:577, in docval.<locals>.dec.<locals>.func_call(*args, **kwargs)
#     576 def func_call(*args, **kwargs):
# --> 577     pargs = _check_args(args, kwargs)
#     578     return func(args[0], **pargs)
#
# File /opt/anaconda3/envs/NWB/lib/python3.9/site-packages/hdmf/utils.py:570, in docval.<locals>.dec.<locals>._check_args(args, kwargs)
#     568     if parse_err:
#     569         msg = '%s: %s' % (func.__qualname__, ', '.join(parse_err))
# --> 570         raise ExceptionType(msg)
#     572 return parsed['args']
#
# TypeError: CustomClassGenerator.set_init.<locals>.__init__: unrecognized argument: 'experimenter'

# %%
nwbfile
# Out:
# root pynwb.file.NWBFile at 0x4883440928
# Fields:
#   experimenter: ['Gina Williams']
#   file_create_date: [datetime.datetime(2025, 10, 7, 10, 14, 24, 744300, tzinfo=tzlocal())]
#   identifier: 09fc26b9-e01a-44b5-8323-61c4a1f9e413
#   lab: Manoli
#   lab_meta_data: {
#     vole_metadata <class 'abc.AssayMetadata'>
#   }
#   session_description: Testing files with new extension.
#   session_id: test1a
#   session_start_time: 2025-10-07 10:14:24.743589-07:00
#   subject: subject pynwb.file.Subject at 0x4883440640
# Fields:
#   age__reference: birth
#   genotype: WT
#   sex: F
#   species: Microtus ochrogaster
#   subject_id: T0001
#
#   timestamps_reference_time: 2025-10-07 10:14:24.743589-07:00
