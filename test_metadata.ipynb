# %%
from datetime import datetime, date
import os
import numpy as np
from uuid import uuid4

from pynwb import NWBHDF5IO, NWBFile, TimeSeries
from pynwb.file import Subject
from pynwb.behavior import (
    BehavioralEpochs,
    BehavioralEvents,
    BehavioralTimeSeries,
    CompassDirection,
    EyeTracking,
    Position,
    PupilTracking,
    SpatialSeries,
)
from pynwb.epoch import TimeIntervals
from pynwb.image import ImageSeries

from ndx_manoli_meta import AssayMetadata

# %%
# NWB metadata
cohort_tag = "test1"
GT = 'behavior'
sdate = date(2024,3,26)
session_description = f'Testing files with new extension.'
experimenter = [
        "Hoglen, Nerissa",
    ]
lab='Manoli'
session_id = 'test1a'
subj = 'T0001'

assay = "partner_preference_test"
exclude_flag = False
duration = 10800.0
room = 'Platyzilla'
timeline = 'sensitized'
ethogram = 'mark1'
experimenter = 'Gina Williams'
timeline_complete = True
colors = np.array([100.0, 100.0, 100.0])
peartag = 'E0001'
seartag = 'E0002'
pGT = 'mut'
sGT = 'WT'
days = 0
pChamb = 'right'
PPT_lane = 2
desc = 'Standard tethered 3 chamber PPT.'

nwbfile = NWBFile(
    session_description=session_description,
    identifier = str(uuid4()),
    session_start_time = datetime.now(),
    lab=lab,
    experimenter=experimenter,
    session_id = session_id,
)

# get session specific subject data
nwbfile.subject = Subject(
    subject_id = subj,
    species = 'Microtus ochrogaster',
    sex = 'F',
    genotype = 'WT'
)

meta = AssayMetadata(
                        assay_type=assay,
                        exclude_flag=exclude_flag,
                        duration=duration,
                        room=room,
                        timeline=timeline,
                        ethogram=ethogram,
                        experimenter=experimenter,
                        timeline_complete=timeline_complete,
                        colors=colors,
                        assay_type__partner_ID=peartag,
                        assay_type__partner_GT=pGT,
                        assay_type__days_post_pairing=days,
                        assay_type__stranger_ID=seartag,
                        assay_type__stranger_GT=sGT,
                        assay_type__PPT_lane = PPT_lane,
                        assay_type__partner_chamber = pChamb,
                        assay_type__description = desc
                        )

# Add the test LabMetaDataExtensionExample to the NWBFile
nwbfile.add_lab_meta_data(lab_meta_data=meta)
# Out:
# C:\Users\nhogl\miniconda3\envs\voc230814\lib\site-packages\pynwb\file.py:471: UserWarning: Date is missing timezone information. Updating to local timezone.
#   args_to_set['session_start_time'] = _add_missing_timezone(session_start_time)
# vole_metadata abc.AssayMetadata at 0x2619345659952
# Fields:
#   assay_type: partner_preference_test
#   assay_type__PPT_lane: 2
#   assay_type__days_post_pairing: 0
#   assay_type__description: Standard tethered 3 chamber PPT.
#   assay_type__partner_GT: mut
#   assay_type__partner_ID: E0001
#   assay_type__partner_chamber: right
#   assay_type__stranger_GT: WT
#   assay_type__stranger_ID: E0002
#   colors: [100. 100. 100.]
#   duration: 10800.0
#   ethogram: mark1
#   exclude_flag: False
#   experimenter: Gina Williams
#   room: Platyzilla
#   timeline: sensitized
#   timeline_complete: True

# %%
nwbfile
# Out:
# root pynwb.file.NWBFile at 0x2619345481024
# Fields:
#   experimenter: ['Gina Williams']
#   file_create_date: [datetime.datetime(2024, 5, 2, 13, 37, 12, 581980, tzinfo=tzlocal())]
#   identifier: ad17a676-87db-4bf8-bdbe-1f8380195c19
#   lab: Manoli
#   lab_meta_data: {
#     vole_metadata <class 'abc.AssayMetadata'>
#   }
#   session_description: Testing files with new extension.
#   session_id: test1a
#   session_start_time: 2024-05-02 13:37:12.578989-07:00
#   subject: subject pynwb.file.Subject at 0x2619345477040
# Fields:
#   age__reference: birth
#   genotype: WT
#   sex: F
#   species: Microtus ochrogaster
#   subject_id: T0001
#
#   timestamps_reference_time: 2024-05-02 13:37:12.578989-07:00
